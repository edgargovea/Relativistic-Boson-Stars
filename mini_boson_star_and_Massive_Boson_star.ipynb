# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.interpolate import interp1d
from scipy.optimize import curve_fit #Use non-linear least squares to fit a function, f, to data.
from scipy.integrate import solve_ivp, quad
from scipy.linalg import eig # Solve an ordinary or generalized eigenvalue problem of a square matrix.

# %%
import metodos as met

# %%
import seaborn as sns

# %%
import plt_conf as conf
conf.general()

# %% [markdown]
# ### Estado Base para n=0 para $\lambda'= ,-1,0,1,10,15,20$ y calculo de la masa para cada caso.

# %%
##Masa vs Radio
wmin, wmax = 0.0, 2.1
p0 = 0.1
nodos = 0
in0 = [1, 1, p0, 0, 0, 0]

datos = []
Lambdas = [-1,0,1,10,15,20]
for i in Lambdas: 
    # in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=50, met='RK45', Rtol=1e-03, Atol=1e-6, limw=1e-14, info=False
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, i, nodos,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos.append([w0, rTemp, nodosPosit, i])
# Out:
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.068160769755732 radio 57.46438933156265
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0726981262163513 radio 59.1505456789699
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0775068306999296 radio 55.24929761275468
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.132385585825886 radio 49.64844747337
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.1692688834899083 radio 45.566424125439674
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.2078739869374477 radio 42.998034304380276

# %%
fig, axes = plt.subplots(nrows= 1, ncols = 2, figsize = (10,5))

colores = colores = sns.color_palette("Greys", 6)

ax0 = axes[1]
ax1 = axes[0]


for j,i in enumerate(datos): 
    #profiles(datos, in0, rmin, Rtol, Atol, info = False)
    r, g, N, Phi, Phi_1, m, dN, N = met.profiles(i, in0, rmin = 0 , Rtol=1e-09, Atol=1e-10, info = False)
    ax1.plot(r, Phi,  label=r'$\lambda^\prime$={}'.format(Lambdas[j]), color = colores[j])
    ax0.plot(r, m, color = colores[j])

ax1.set_xlim(0,25)
ax0.set_xlim(0,25)
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$\sigma$')
ax0.set_xlabel(r'$x$')
ax0.set_ylabel(r'$M$')
ax1.axhline(y=0, color='r', linestyle='--')
ax1.legend(fontsize = 12)
plt.savefig("RelativisticBoson_starLambdas.pdf")
plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_5371/2448371548.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, axes = plt.subplots(nrows= 1, ncols = 2, figsize = (10,5))

# %%
colores = sns.color_palette("RdBu", 12)
print(colores)
# Out:
# [(0.6230680507497116, 0.07012687427912341, 0.1566320645905421), (0.7727797001153403, 0.243598615916955, 0.2392156862745098), (0.8761245674740484, 0.46136101499423293, 0.3671664744329104), (0.9589388696655133, 0.659515570934256, 0.5257208765859284), (0.9866205305651673, 0.8256055363321797, 0.7379469434832755), (0.9773933102652826, 0.9277201076509035, 0.8985005767012687), (0.9131103421760862, 0.9423298731257209, 0.95840061514802), (0.7808535178777396, 0.8783544790465208, 0.9301038062283737), (0.5870818915801617, 0.779930795847751, 0.8747404844290658), (0.3599384851980012, 0.6379853902345254, 0.7979238754325261), (0.2, 0.4934256055363322, 0.7222606689734717), (0.10142252979623223, 0.34602076124567477, 0.5995386389850058)]

# %% [markdown]
# ### Mini-Boson Star Excited States $\lambda = 0$

# %%
##Masa vs Radio
wmin, wmax = 0.0, 2.1
p0 = 0.1
nodos = [0,1,2,3]

in0 = [1, 1, p0, 0, 0, 0]

datos = []
Lambdas = [0]

for j in nodos: 
    for i in Lambdas: 
        # in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=50, met='RK45', Rtol=1e-03, Atol=1e-6, limw=1e-14, info=False
        w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, i, j,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,
                   limw=1e-14, info=False)
        datos.append([w0, rTemp, nodosPosit, i])
# Out:
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0726981262163513 radio 59.1505456789699
# Finding a profile with  1 nodes
# Maxima precisión alcanzada 1.0986062145339972 radio 77.59179310620965
# Finding a profile with  2 nodes
# Maxima precisión alcanzada 1.1107053449093267 radio 94.55162648439078
# Finding a profile with  3 nodes
# Found 1.1184262280435178

# %%
fig, axes = plt.subplots(nrows= 1, ncols = 2, figsize = (10,5))

ax0 = axes[1]
ax1 = axes[0]


for j,i in enumerate(datos): 
    #profiles(datos, in0, rmin, Rtol, Atol, info = False)
    r, g, N, Phi, Phi_1, m, dN, N = met.profiles(i, in0, rmin = 0 , Rtol=1e-09, Atol=1e-10, info = False)
    ax1.plot(r, Phi,  label=r'$n$={}'.format(nodos[j]), color = colores[j])
    ax0.plot(r, m, color = colores[j])

ax1.set_xlim(0,70)
ax0.set_xlim(0,60)
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$\sigma$')
ax0.set_xlabel(r'$x$')
ax0.set_ylabel(r'$M$')
ax1.axhline(y=0, color='r', linestyle='--')
ax1.legend(fontsize = 12)
plt.savefig("RelativisticBoson_starExcitedn.pdf")
plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_5371/249664886.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, axes = plt.subplots(nrows= 1, ncols = 2, figsize = (10,5))

# %% [markdown]
# ### Free Case $\lambda =0$, no nodes $n=0$

# %%
wmin, wmax =0.0, 2.1
p0 = 0.5
nodos = 0
in0 = [1, 0.24, p0, 0, 0, 0]

datos = []
Lambdas = [0]
for i in Lambdas: 
    # in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=50, met='RK45', Rtol=1e-03, Atol=1e-6, limw=1e-14, info=False
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, i, nodos,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos.append([w0, rTemp, nodosPosit, i])
    
r, g, N, Phi, Phi_1, m, dN, NP = met.profiles(datos[0], in0, rmin = 0 , Rtol=1e-09, Atol=1e-10, info = False)
# Out:
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 0.7943848513249014 radio 29.805983160279734

# %%
fig, ax1 = plt.subplots(nrows= 1, ncols = 1, figsize = (5,5))

#ax0 = axes[1]
#ax1 = axes[0]

#ax0.plot(r, dN)
#ax0.plot(r, m)
ax1.plot(r, Phi, label = '$\sigma(r)$', color = 'black')
ax1.plot(r, g, label = '$A(r)$', color = 'gray')
ax1.plot(r, N, label = '$B(r)$', color = 'darkgray')
ax1.plot(r, Phi_1, label = '$d\sigma(r)/dr$', color = 'red')
#ax0.axhline(y=0, color='r', linestyle='--')
ax1.axhline(y=0, color='r', linestyle='--')
ax1.axhline(y=1.0, color='r', linestyle='--')
#ax1.axhline(y=4.1, color='r', linestyle='--')
plt.text(16, 0.25, r'$\tilde{\omega}=0.79$', fontsize=12, ha='right')
ax1.set_xlabel(r'$r$')
#ax0.set_xlabel(r'$r$')
#ax0.set_ylabel(r'$M(r)$')
ax1.legend(loc='best', fontsize=12) 
ax1.set_xlim(0, 20)
plt.savefig("RelativisticBoson_starFreeCase.pdf")
plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_3555/688538893.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax1 = plt.subplots(nrows= 1, ncols = 1, figsize = (5,5))

# %% [markdown]
# ### Energía vs N

# %%
## DIvidir el proceso para varias omegas w

wmin, wmax = 0.0, 2
p0 = np.linspace(0.001,0.5,20)
nodos = 0
Number = []
dNumber = []
massa = []
phi00 = []

Lambdas = 0

for i in p0: 
    in0 = [1, 1, i, 0, 0, 0]
    # in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=50, met='RK45', Rtol=1e-03, Atol=1e-6, limw=1e-14, info=False
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, Lambdas, nodos,rmin=0, rmax=40, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos = [w0, rTemp, nodosPosit, Lambdas]
    
    r, g, N, Phi, Phi_1, m, dN, NP = met.profiles(datos, in0, rmin = 0, Rtol=1e-09, Atol=1e-10, info = True)
    
    if Phi[-1] > 0.1: 
        continue
    else: 
        Number.append(NP)
        dNumber.append(dN[-1])
        massa.append(m[-1])
        phi00.append(Phi[0]) 
        
wmin, wmax = 0.0, 5
p0 = np.linspace(0.0001,1.5,20)

for i in p0: 
    in0 = [1, 1, i, 0, 0, 0]
    # in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=50, met='RK45', Rtol=1e-03, Atol=1e-6, limw=1e-14, info=False
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, Lambdas, nodos,rmin=0, rmax=40, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos = [w0, rTemp, nodosPosit, Lambdas]
    
    r, g, N, Phi, Phi_1, m, dN, NP = met.profiles(datos, in0, rmin = 0, Rtol=1e-09, Atol=1e-10, info = True)
    
    if Phi[-1] > 0.1: 
        continue
    else: 
        Number.append(NP)
        dNumber.append(dN[-1])
        massa.append(m[-1])
        phi00.append(Phi[0]) 

datos = [Number, dNumber, massa, phi00]
# Out:
# Finding a profile with  0 nodes
# Found 1.001953125
# /Users/edgarpreciado/Downloads/Boson_star_Chapter/Configuraciones_Bosones/Mini_Boson_stars/metodos.py:184: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(sol2.t, sol2.y[4])
# Finding a profile with  0 nodes
# Found 1.01824951171875
# Finding a profile with  0 nodes
# Found 1.0368967056274414
# Finding a profile with  0 nodes
# Found 1.0566683039069176
# Finding a profile with  0 nodes
# Found 1.0776431253179908
# Finding a profile with  0 nodes
# Found 1.0999081632326124
# Finding a profile with  0 nodes
# Found 1.123558358718583
# Finding a profile with  0 nodes
# Found 1.1486974328848873
# /Users/edgarpreciado/Downloads/Boson_star_Chapter/Configuraciones_Bosones/Mini_Boson_stars/metodos.py:165: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   N = quad(NInt,rmin, rfin)[0]
# Finding a profile with  0 nodes
# Found 1.1754388446726267
# /Users/edgarpreciado/Downloads/Boson_star_Chapter/Configuraciones_Bosones/Mini_Boson_stars/metodos.py:165: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   N = quad(NInt,rmin, rfin)[0]
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.2039068614159447 radio 37.56017817741383
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.2342377597383773 radio 36.45695144463702
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.2665811732577907 radio 34.581620749308264
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.3011016054992268 radio 34.325945122055685
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.3379801284066133 radio 32.82593137141317
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.3774162888798998 radio 31.80382198313549
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.4196302477568992 radio 30.804819926836156
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.4648651774786714 radio 30.72817192857744
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.5133899461329605 radio 29.40721444575204
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.5655021163861562 radio 29.273961976009467
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.621531287617259 radio 28.40577828732809
# Finding a profile with  0 nodes
# Found 0.625
# Finding a profile with  0 nodes
# Found 0.625
# Finding a profile with  0 nodes
# Found 0.625
# Finding a profile with  0 nodes
# Found 0.625
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.3007086162432735 radio 33.45731062533437
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.419402687809832 radio 30.466928623116683
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.565534589772053 radio 28.785654941542404
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.74727477726476 radio 28.531099950434957
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.9757545381613362 radio 27.157182529205357
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.2661737867678333 radio 29.36763596792213
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.6391673610590693 radio 27.04990590994441
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 3.122237025814787 radio 27.994670906589683
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 3.750785253531088 radio 29.357544186677938
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.568303139214134 radio 30.74454675940702
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.999999999999982 radio 2.7835243561361
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.999999999999982 radio 1.81171861794292
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.999999999999982 radio 1.4191927845676362
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.999999999999982 radio 1.191890587063684
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.999999999999982 radio 1.0391066966194766
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.999999999999982 radio 0.9274193570183363

# %%
np.save('ShootingMvsSig.npy', datos, allow_pickle=True)

# %%
#plt.scatter(phi00,massa)
#plt.scatter(phi00,Number)
#plt.scatter(phi00,dNumber)


masss  = interp1d(phi00, massa, kind='quadratic')
ParticleN= interp1d(phi00, dNumber, kind='quadratic')
phi = np.linspace(phi00[0],phi00[-1],1000)

plt.figure(figsize=(7, 5))

plt.plot(phi,masss(phi), color = 'black')
plt.plot(phi,ParticleN(phi), color = 'gray')
plt.plot(phi,ParticleN(phi)-masss(phi), color = 'red')


plt.text(0.8, 0.47, '$M$', fontsize=12, ha='right')
plt.text(0.8, 0.35, '$m_0N$', fontsize=12, ha='right')
plt.text(0.8, 0.01, '$E_B$', fontsize=12, ha='right')


# Agregar un título y etiquetas a los ejes
#plt.title("Gráfica de ejemplo")
plt.ylabel("$M$, $m_0N$")
plt.xlabel("$\sigma_0$")
plt.xlim(0, 1.0)

plt.axhline(y=0.0, color='black', linestyle='--', linewidth=0.5)
plt.axvline(x=0.54, color='black', linestyle='--', linewidth=0.5)
plt.axvline(x=0.27, color='black', linestyle='-.', linewidth=0.5)


plt.savefig("RelativisticBoson_NMvsS.pdf")


plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_5371/2457863683.py:12: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(phi,masss(phi), color = 'black')

# %% [markdown]
# ### Grafiquemos el comportamiento de Una estrella de bosones libre confrome elegimos $\omega$ muy grande o muy pequeño

# %%
p0 = 0.1
in0 = [1, 1, p0, 0, 0, 0]
Lambda = 0
nodos = 0

datos = []
wmin = [0.0, 0, 0]
wmax = [1.9,2.1, 2.2] #Elegimos un valor muy pequeño de w= 0.7 y un valor muy grande w= 10
for j,i in enumerate(wmax): 
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin[j], i, Lambda, nodos,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,limw=1e-14, info=False)
    datos.append([w0, rTemp, nodosPosit, Lambda])
# Out:
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0726981262163486 radio 57.51005921510574
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0726981262163513 radio 59.1505456789699
# Finding a profile with  0 nodes
# Found 0.55

# %%
datos = [[0.9726981262164745, 57.25684336615575,0,0],
[1.0726981262164745, 57.25684336615575,0,0],
[1.09000000000000113, 57.25684336615575,0,0]]

p0 = 0.1
in0 = [1, 1, p0, 0, 0, 0]
Lambda = 0
nodos = 0


fig, axes = plt.subplots(nrows= 1, ncols = 3, figsize = (18,6))

ax0 = axes[1]
ax1 = axes[0]
ax2 = axes[2]

for j,i in enumerate(datos): 
    #profiles(datos, in0, rmin, Rtol, Atol, info = False)
    r, g, N, Phi, Phi_1, m, dN, NP = met.profiles(i, in0, rmin = 0 , Rtol=1e-09, Atol=1e-10, info = False)
    if j==0: 
        ax1.plot(r, Phi, label = r'$\tilde{\omega} = 0.972 $', color = 'black')
    if j==1: 
        ax0.plot(r, Phi, label = r'$\tilde{\omega} = 1.072$', color = 'black')
    if j==2: 
        ax2.plot(r, Phi, label = r'$\tilde{\omega} = 1.090$', color = 'black')

ax1.set_xlim(0,40)
ax0.set_xlim(0,40)
ax2.set_xlim(0,40)
ax1.axhline(y=0, color='r', linestyle='--')
ax0.axhline(y=0, color='r', linestyle='--')
ax2.axhline(y=0, color='r', linestyle='--')
ax2.set_xlabel(r'$x$')
ax1.set_ylabel(r'$\sigma$')
ax0.set_xlabel(r'$x$')
ax1.set_xlabel(r'$x$')
ax0.legend()
ax1.legend()
ax2.legend()
plt.savefig("RelativisticBoson_Shooting.pdf")
plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_3555/2036799478.py:11: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, axes = plt.subplots(nrows= 1, ncols = 3, figsize = (18,6))

# %%
datos = [[0.9726981262164745, 57.25684336615575],
[1.0726981262164745, 57.25684336615575],
[1.09000000000000113, 57.25684336615575]]

# %%
# [g, g', N, N', Phi, Phi'] -> [g0, g1, n0, n1, p0, p1]
rmin = 0
 # [g0, n0, Phi0, Phi'0]
npt = 3800
Rtol = 1e-09
Atol = 1e-10

fig, axes = plt.subplots(nrows=1, ncols=3)
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]

for j,i in enumerate(datos): 
        w = i[0]
        arg = [w, 0]
        sol2 = solve_ivp(systemBS, [rmin, i[1]], in0, args=(arg,), method='RK45', rtol=Rtol, atol=Atol)
        
        if j == 0:
                ax1.plot(sol2.t, sol2.y[2], label = r'$\omega$ = {:.3f}'.format(w))
    
        if j== 1:
            
                ax2.plot(sol2.t, sol2.y[2], label = r'$\omega$ = {:.3f}'.format(w))
            
        if j==2 : 
                ax3.plot(sol2.t, sol2.y[2], label = r'$\omega$ = {:.3f}'.format(w))
       
        print(w, i[1])


ax1.legend(loc="upper right")
ax1.set_xlim(0, 30)
ax2.set_xlim(0, 30)
ax3.set_xlim(0, 30)
ax1.set_xlabel(r'$r[m^-1]$')
ax1.set_ylabel(r'$\phi/M_{pl}$')
ax2.set_xlabel(r'$r[m^-1]$')
ax2.set_ylabel(r'$\phi/M_{pl}$')
ax3.set_xlabel(r'$r[m^-1]$')
ax3.set_ylabel(r'$\phi/M_{pl}$')
ax1.axhline(0.0,color='black',ls='--')
ax2.axhline(0.0,color='black',ls='--')
ax3.axhline(0.0,color='black',ls='--')
#l2 = ax2.axhline(sol2.y[4][-1],color='black',ls='-')
#l2.set_label(r'$M$ ={:.3f}'.format(sol2.y[4][-1]))
#ax1.set_title(r'Relativistic Boson Star, $n=0$", $\lambda' = 0$.')
#ax2.set_title(r'Mass of a Relativistic Boson Star, $n=0$", $\lambda' = 0$.')
fig.tight_layout()
#ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')
plt.legend()
plt.savefig("mini_boson_w_behavior.png") # save as pn

plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_6693/3125184284.py:9: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, axes = plt.subplots(nrows=1, ncols=3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_6693/3125184284.py in <module>
#      15         w = i[0]
#      16         arg = [w, 0]
# ---> 17         sol2 = solve_ivp(systemBS, [rmin, i[1]], in0, args=(arg,), method=met, rtol=Rtol, atol=Atol)
#      18
#      19         if j == 0:
#
# NameError: name 'systemBS' is not defined

# %% [markdown]
# ### Configuracipon para estado excitado para n =0,1,2,3 $\Lambda = 0$.  Y masa correspondiente

# %%
# def Freq_solveNodos(system, in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=1e03, met='RK45', Rtol=1e-09, Atol=1e-10,limw=1e-14, info=False):
##Masa vs Radio
wmin, wmax = 0.5, 5
p0 = 0.1
in0 = [1, 1, p0, 0, 0]

datos = []
n = [0,1,2,3]
for i in n: 
    w0, rTemp, nodosPosit = met.Freq_solveNodos(systemBS, in0, wmin, wmax, 0, i)
    datos.append([w0, rTemp, nodosPosit])
# Out:
# Finding a profile with  0 nodes
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_2330/4271438589.py in <module>
#       8 n = [0,1,2,3]
#       9 for i in n:
# ---> 10     w0, rTemp, nodosPosit = met.Freq_solveNodos(systemBS, in0, wmin, wmax, 0, i)
#      11     datos.append([w0, rTemp, nodosPosit])
#
# ~/Downloads/Boson_star_Chapter/Configuraciones_Bosones/Mini_Boson_stars/metodos.py in Freq_solveNodos(in0, wmin, wmax, Lambda, nodos, rmin, rmax, met, Rtol, Atol, limw, info)
#     103
#     104     while True:
# --> 105         w0 = (wmax+wmin)/2
#     106         arg = [w0, Lambda]
#     107
#
# TypeError: unsupported operand type(s) for +: 'float' and 'list'

# %%
# [g, g', N, N', Phi, Phi'] -> [g0, g1, n0, n1, p0, p1]
rmin = 0
 # [g0, n0, Phi0, Phi'0]
npt = 3800
met = 'RK45'
Rtol = 1e-09
Atol = 1e-10

fig, axes = plt.subplots(nrows=1, ncols=2)
ax1 = axes[0]
ax2 = axes[1]

for j,i in enumerate(datos): 
        w = i[0]
        arg = [w, 0]
        sol2 = solve_ivp(systemBS, [rmin, i[1]], in0, args=(arg,), method=met, rtol=Rtol, atol=Atol)

        ax1.plot(sol2.t, sol2.y[2], label = r'$n$ = {}'.format(j))
        ax2.plot(sol2.t, sol2.y[4])
        print(w, i[1])


ax1.legend(loc='best')
ax1.set_xlim(0, 70)
ax2.set_xlim(0, 55)
ax1.set_xlabel(r'$r[m^-1]$')
ax1.set_ylabel(r'$\phi/M_{pl}$')
ax2.set_xlabel(r'$r[m^-1]$')
ax2.set_ylabel(r'$M/m_{pl}^2/m_0$')
ax1.axhline(0.0,color='black',ls='--')
#l2 = ax2.axhline(sol2.y[4][-1],color='black',ls='-')
#l2.set_label(r'$M$ ={:.3f}'.format(sol2.y[4][-1]))
#ax1.set_title(r'Relativistic Boson Star, $n=0$", $\lambda' = 0$.')
#ax2.set_title(r'Mass of a Relativistic Boson Star, $n=0$", $\lambda' = 0$.')
#fig.tight_layout()
#ax2.legend(loc='best')
#plt.legend()
plt.savefig("mini_boson_n0123.png") # save as pn
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Configuracipon para estado excitado para n =0 $\Lambda = 0,10,50,300$.  Y masa correspondiente.

# %%
##Masa vs Radio
wmin, wmax = 0.5,5
p0 = 0.1
in0 = [1, 1, p0, 0, 0]

datos = []
Lambdas = [-1,0,10,15,20]
for i in Lambdas: 
    w0, rTemp, nodosPosit = Freq_solveNodos(systemBS, in0, wmin, wmax, i, 0)
    datos.append([w0, rTemp, nodosPosit])
# Out:
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0681607697562558 radio 56.387541523707554
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0726981262164745 radio 57.25684336615575
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.1323855858241973 radio 50.16701856995966
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.1692688834875415 radio 50.27301396466911
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.2078739869346276 radio 42.90843269525886

# %%
### Para el caso libre Grafiquemos. 

# [g, g', N, N', Phi, Phi'] -> [g0, g1, n0, n1, p0, p1]
rmin = 0
 # [g0, n0, Phi0, Phi'0]
npt = 3800
met = 'RK45'
Rtol = 1e-09
Atol = 1e-10

fig, axes = plt.subplots(nrows=1, ncols=2)
ax1 = axes[0]
ax2 = axes[1]

for j,i in enumerate(datos): 
        w = i[0]
        arg = [w, Lambdas[j]]
        sol2 = solve_ivp(systemBS, [rmin, i[1]], in0, args=(arg,), method=met, rtol=Rtol, atol=Atol)

        ax1.plot(sol2.t, sol2.y[2], label = r'$\lambda$ = {}'.format(Lambdas[j]))
        ax2.plot(sol2.t, sol2.y[4])
        print(w, i[1])


ax1.legend(loc="upper right")
ax1.set_xlim(0, 30)
ax2.set_xlim(0, 40)
ax1.set_xlabel(r'$r[m^-1]$')
ax1.set_ylabel(r'$\phi/M_{pl}$')
ax2.set_xlabel(r'$r[m^-1]$')
ax2.set_ylabel(r'$M/m_{pl}^2/m_0$')
ax1.axhline(0.0,color='black',ls='--')
#l2 = ax2.axhline(sol2.y[4][-1],color='black',ls='-')
#l2.set_label(r'$M$ ={:.3f}'.format(sol2.y[4][-1]))
#ax1.set_title(r'Relativistic Boson Star, $n=0$", $\lambda' = 0$.')
#ax2.set_title(r'Mass of a Relativistic Boson Star, $n=0$", $\lambda' = 0$.')
# save as pn
fig.tight_layout()
ax2.legend(loc='best')
plt.legend()
plt.savefig("self_interactive_boson_star.png") 

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Grafiquemos la Relacion Massa Total vs $\sigma_{0}$

# %%
##Masa vs Radio
PHI0 =[]
wmin, wmax = 0.0, 2
p0 = np.linspace(0.0, 0.5, 10)

Lambda = 0
nodos = 0

datos = []

for i in p0: 
    in0 = [1, 1, i, 0, 0, 0]
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, Lambda, nodos,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos.append([w0, rTemp, nodosPosit, 0])
    PHI0.append(i)
wmin, wmax = 0.0, 5
p0 = np.linspace(0.5,1.0, 10)

for i in p0: 
    in0 = [1, 1, i, 0, 0, 0]
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, Lambda, nodos,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos.append([w0, rTemp, nodosPosit, 0])
    PHI0.append(i)
wmin, wmax = 0.0, 5
p0 = np.linspace(0.5,1.0, 10)

for i in p0: 
    in0 = [1, 1, i, 0, 0, 0]
    w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, Lambda, nodos,rmin=0, rmax=100, met='RK45', Rtol=1e-09, Atol=1e-10,
               limw=1e-14, info=False)
    datos.append([w0, rTemp, nodosPosit, 0])
    PHI0.append(i)
np.save('ShootingMvsSig.npy', datos, allow_pickle=True)
# Out:
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.4210854715202004e-14 radio 11.111110999999998
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0383833385486838 radio 73.65857642113744
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.0818283974376328 radio 55.868034631309726
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.131136194541412 radio 45.18276937361676
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.1872707517793089 radio 39.19760617549735
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.2513988032616652 radio 35.63288319504753
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.324940377850325 radio 32.83746886839931
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.4096333616060548 radio 30.953572653171477
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.507615903628576 radio 29.82323067146999
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.621531287617259 radio 28.40577828732809
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.6215312876172483 radio 29.506191056182114
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.7546604186164494 radio 29.216288449082253
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.9110868753236865 radio 29.2765972336803
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.0958976170855514 radio 27.078797836664673
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.3154173576021897 radio 27.963029825961847
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.577464260689606 radio 28.514485015798716
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.8915976313253644 radio 27.200715066256553
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 3.269308180531194 radio 29.493290557969278
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 3.7240956968179795 radio 30.14070321205207
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.2714294141555875 radio 30.89236056411693
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.6215312876172483 radio 29.506191056182114
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.7546604186164494 radio 29.216288449082253
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 1.9110868753236865 radio 29.2765972336803
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.0958976170855514 radio 27.078797836664673
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.3154173576021897 radio 27.963029825961847
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.577464260689606 radio 28.514485015798716
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 2.8915976313253644 radio 27.200715066256553
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 3.269308180531194 radio 29.493290557969278
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 3.7240956968179795 radio 30.14070321205207
# Finding a profile with  0 nodes
# Maxima precisión alcanzada 4.2714294141555875 radio 30.89236056411693

# %%
print(len(datos), len(PHI0))
# Out:
# 30 30

# %%
np.save('ShootingMvsSig.npy', datos, allow_pickle=True)
#datos = np.load(ShootingMvsSig.npy)

# %%
# [g, g', N, N', Phi, Phi'] -> [g0, g1, n0, n1, p0, p1]
MasaTotal = []
phi0 = []

for i, dato in enumerate(datos): 
    w = dato[0]
    arg = [w, 0]
    in0 = [1, 1, PHI0[i], 0, 0, 0]
    #sol2 = solve_ivp(systemBS, [rmin, dato[1]], in0, args=(arg,), method=met, rtol=Rtol, atol=Atol)
    r, g, N, Phi, Phi_1, m, dN, NP = met.profiles(dato, in0, rmin = 0, Rtol=1e-09, Atol=1e-10, info = False)
    
    if Phi[-1] > 0.1: 
        continue
        
    else: 
    
        MasaTotal.append(m[-1])
        phi0.append(Phi[0])

# %%
for j,i in enumerate(MasaTotal): 
    if i == max(MasaTotal): 
        print(j,phi0[j], max(MasaTotal))
# Out:
# 5 0.2777777777777778 0.6329135460623307

# %%
plt.scatter(phi0, MasaTotal)
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_7869/4011194652.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(phi0, MasaTotal)

# %%
Sigma0_non = [0.8696623188405797,
 2.1740057971014495,
 3.043568115942029,
 3.478349275362319,
 4.347911594202898,
 4.782692753623188,
 5.652255072463768,
 6.087036231884057,
 6.521817391304348,
 6.956598550724637,
 8.695723188405797,
 9.565285507246376,
 10.434847826086955,
 10.869628985507246,
 11.739191304347825,
 12.173972463768115,
 14.347878260869564,
 14.782659420289853,
 15.652221739130434,
 16.087002898550722,
 17.826127536231883,
 18.695689855072462,
 19.130471014492752,
 20.43481449275362,
 21.304376811594203,
 22.173939130434782,
 22.60872028985507,
 24.34784492753623,
 24.78262608695652,
 25.21740724637681,
 27.39131304347826,
 29.130437681159417,
 30.0]
Massa_non = [3.234346125143957,
 5.1137738338089695,
 6.050659038514389,
 6.468413313169075,
 7.2318851461185965,
 7.584857200834309,
 8.245595838564348,
 8.556853786487622,
 8.8571802911545,
 9.147652086714464,
 10.227371248856812,
 10.726551851960311,
 11.203513137032832,
 11.43453552181677,
 11.883113841823592,
 12.101168975187889,
 13.137266477930005,
 13.334829076692982,
 13.721423340268732,
 13.910692091377117,
 14.643324022083476,
 14.996223871382018,
 15.16959545881441,
 15.678211452588032,
 16.008313662815933,
 16.33174510956854,
 16.491082265826783,
 17.113602141403398,
 17.26572541906331,
 17.416520037897257,
 18.151712045835094,
 18.719087428048912,
 18.99642140280143]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (10,5))
ax1 = axes[0]
ax2 = axes[1]


##################################
#ax1.plot(phi0, MasaTotal)

NRBstarML0n1   = interp1d(phi0, MasaTotal, kind='linear', fill_value='extrapolate')
NRRadioL0n1 = np.linspace(phi0[0],phi0[-1],3000)
ax1.plot(NRRadioL0n1,NRBstarML0n1(NRRadioL0n1))
##################################

ax2.plot(Sigma0_non,Massa_non, label = r'$\lambda$ = 0, $n$=0.')
ax1.scatter(0.2777777777777778,max(MasaTotal), label = r'$Masa\;de\;Kaup$ = {:.3f}'.format(max(MasaTotal)))
#ax2.scatter(0.88245,Massa_non[0],label = r'$\sigma_0$ = 1')

ax1.legend(loc="lower left")
ax2.legend(loc="best")

ax1.set_xlim(0.0976470588235294, 1.0)
ax1.set_ylim(0.0, 0.7)
ax2.set_xlim(0.88245, 30.0)
ax1.set_xlabel(r'$\sigma_{0}$')
ax1.set_ylabel(r'$M_r$')
ax2.set_xlabel(r'$\sigma_{0}$')
ax2.set_ylabel(r'$M_N$')
#ax1.axvline(0.31676470588235295,color='black',ls='--')
#ax1.axvline(x=3, color='r', linestyle='--', label='Línea vertical')
ax1.axhline(max(MasaTotal),color='black',ls='--')
#\sigma_ma = 0.2777777777777778 M = Max = 0.6329135460623307
ax1.fill_betweenx(y=[0,max(MasaTotal)+0.1],x1=0.0976470588235294, x2=0.2777778, color='grey', alpha=0.5, label='Franja vertical entre x=2 y x=4')
#ax1.set_label(r'$M$ ={:.3f}'.format(sol2.y[4][-1]))
#ax1.set_title(r'Relativistic mini-Boson Star.')
#ax2.set_title(r'Non-Relativistic Boson Star.')
fig.tight_layout()
plt.savefig("MassVs_Sigma00.pdf") 
plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_7869/3596157258.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (10,5))

# %% [markdown]
# ### Massa Vs Lambda

# %%
massa0 = []
phi0 = []
massa10 = []
phi10 = []
massa15 = []
phi15 = []
massa25 = []
phi25 = []

# %%
## DIvidir el proceso para varias omegas w
wmin, wmax = 0.0, 7
p0 = np.linspace(0.4,0.5,15)
nodos = 0

Lambdas = [25] 

for j in Lambdas: 
    for i in p0: 
        in0 = [1, 1, i, 0, 0, 0]
        # in0, wmin, wmax, Lambda, nodos, rmin=0, rmax=50, met='RK45', Rtol=1e-03, Atol=1e-6, limw=1e-14, info=False
        w0, rTemp, nodosPosit = met.Freq_solveNodos(in0, wmin, wmax, j, nodos,rmin=0, rmax=30, met='RK45', Rtol=1e-09, Atol=1e-10,
                   limw=1e-14, info=False)
        datos = [w0, rTemp, nodosPosit, j]

        r, g, N, Phi, Phi_1, m, dN, NP = met.profiles(datos, in0, rmin = 0, Rtol=1e-09, Atol=1e-10, info = False)
    
        if Phi[-1] > 0.1: 
            continue
        else:
            plt.plot(r, Phi)
            

            if j== 0:
                massa0.append(m[-1])
                phi0.append(Phi[0]) 
                
            elif j== 10:
                massa10.append(m[-1])
                phi10.append(Phi[0]) 
                
            elif j== 15:
                massa15.append(m[-1])
                phi15.append(Phi[0])
                
            elif j== 25:
                massa25.append(m[-1])
                phi25.append(Phi[0])
# Out:
# Finding a profile with  0 nodes
# Found 1.75
# Finding a profile with  0 nodes
# Found 1.75
# Finding a profile with  0 nodes
# Found 3.5317443955927104
# Finding a profile with  0 nodes
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_3650/4104004349.py:21: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(r, Phi)
# Found 3.601119241175013
# Finding a profile with  0 nodes
# Found 3.671347462974097
# Finding a profile with  0 nodes
# Found 3.7424438308967325
# Finding a profile with  0 nodes
# Found 3.814423697139418
# Finding a profile with  0 nodes
# Found 3.8873029945089286
# Finding a profile with  0 nodes
# Found 3.9610982361425897
# Finding a profile with  0 nodes
# Found 4.035826516544319
# Finding a profile with  0 nodes
# Found 4.11150551386163
# Finding a profile with  0 nodes
# Found 4.188153493334767
# Finding a profile with  0 nodes
# Found 3.5
# Finding a profile with  0 nodes
# Found 3.5
# Finding a profile with  0 nodes
# Found 3.5

# %%
#Datos_Salvados = [massa0,phi0,massa10,phi10,massa15,phi15,massa25,phi25]
#np.save('MasaVsLambdas.npy', Datos_Salvados , allow_pickle=True)
datos = np.load('MasaVsLambdas.npy',allow_pickle=True)

# %%
def del_rep(x,y):
    for k, i in enumerate(x): 
        if x.count(i) >= 2:
            x.pop(k)
            y.pop(k)
        else:
            continue 
    return x, y

# %%
phi0, massa0 = del_rep(datos[1],datos[0])
phi10, massa10 = del_rep(datos[3],datos[2])
phi15, massa15 = del_rep(datos[5],datos[4])
phi25, massa25 = del_rep(datos[7],datos[6])

# %%
for k,i in enumerate(phi25):
    print('n.', k,i, massa25[k])
# Out:
# n. 0 0.025 0.45909574469743014
# n. 1 0.07500000000000001 1.3647151311653052
# n. 2 0.05 0.9734593646708363
# n. 3 0.022222222222222223 0.4282783230363677
# n. 4 0.044444444444444446 0.8652651647904541
# n. 5 0.06666666666666667 1.2516271437201547
# n. 6 0.15789473684210525 1.6048192796546605
# n. 7 0.1736842105263158 1.5554904761891144
# n. 8 0.015789473684210527 0.3140420313322101
# n. 9 0.031578947368421054 0.6321780708011366
# n. 10 0.04736842105263158 0.921285784427774
# n. 11 0.06315789473684211 1.1977803453390596
# n. 12 0.07894736842105263 1.411305237241388
# n. 13 0.2368421052631579 1.3226862952099534
# n. 14 0.25263157894736843 1.2683714837106657
# n. 15 0.10526315789473684 1.6090576279473465
# n. 16 0.12631578947368421 1.652004819892642
# n. 17 0.3157894736842105 1.0901710695146116
# n. 18 0.0 0.0
# n. 19 0.16842105263157894 1.5730247532059254
# n. 20 0.35789473684210527 1.0071102254322415
# n. 21 0.37894736842105264 0.9755750883871726
# n. 22 0.4 0.95025218015487
# n. 23 0.4142857142857143 0.9364305572414858
# n. 24 0.42142857142857143 0.9304980793974746
# n. 25 0.4285714285714286 0.9251989957809309
# n. 26 0.4357142857142857 0.9205187918790292
# n. 27 0.44285714285714284 0.9164425552755087
# n. 28 0.45 0.9129548995261499
# n. 29 0.45714285714285713 0.9100399003766543
# n. 30 0.4642857142857143 0.9076810350434688
# n. 31 0.4714285714285714 0.9058611241676522
# n. 32 0.4785714285714286 0.904562311126036

# %%
#phi10.pop(0)
#massa10.pop(0)
#plt.scatter(phi0, massa0, label = '0')
#plt.scatter(phi10,massa10, label = '10')
#plt.scatter(phi15,massa15, label = '15')
plt.scatter(phi25,massa25, label = '25')

masa_25  = interp1d(phi25, massa25, kind='quadratic')
phi_25 = np.linspace(phi25[18],phi25[-1],1000)
plt.plot(phi_25,masa_25(phi_25), label = '$\lambda^{\prime}=25$', color = 'black')




plt.legend()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_5970/3457632852.py:6: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(phi25,massa25, label = '25')

# %%
plt.figure(figsize=(7, 5))

#plt.scatter(phi0, massa0, label = 'L = 0')
#plt.scatter(phi10, massa10, label = 'L = 10')
#plt.scatter(phi15, massa15, label = 'L = 15')
#plt.scatter(phi25, massa25, label = 'L = 25')


masss_0  = interp1d(phi0, massa0, kind='quadratic')
phi_0 = np.linspace(phi0[7],phi0[-1],1000)
plt.plot(phi_0,masss_0(phi_0), label = '$\lambda^{\prime}=0$',  color = 'darkgray')

masss1  = interp1d(phi15, massa15, kind='quadratic')
phi = np.linspace(phi15[3],phi15[-1],1000)
plt.plot(phi,masss1(phi), label = '$\lambda^{\prime}=15$', color = 'darkred')

masa_10  = interp1d(phi10, massa10, kind='quadratic')
phi_10 = np.linspace(phi10[3],phi10[-1],1000)
plt.plot(phi_10,masa_10(phi_10), label = '$\lambda^{\prime}=10$', color = 'gray')

masa_25  = interp1d(phi25, massa25, kind='quadratic')
phi_25 = np.linspace(phi25[18],phi25[-1],1000)
plt.plot(phi_25,masa_25(phi_25), label = '$\lambda^{\prime}=25$', color = 'black')


plt.text(0.245, 1.47, '$\lambda= 25$', fontsize=12, ha='right')
plt.text(0.17, 1.40, '$\lambda= 15$', fontsize=12, ha='right')
plt.text(0.18, 1.2, '$\lambda= 10$', fontsize=12, ha='right')
plt.text(0.2, 0.67, '$\lambda= 0$', fontsize=12, ha='right')


plt.ylabel("$M$")
plt.xlabel("$\sigma_0$")
plt.xlim(0,0.44)
plt.legend()


plt.savefig("MassvsLambda.pdf")

plt.show()
# Out:
# /var/folders/1k/wc33r23j7pd72wpg_rynb4hr0000gn/T/ipykernel_5970/3711618378.py:11: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(phi_0,masss_0(phi_0), label = '$\lambda^{\prime}=0$',  color = 'darkgray')
